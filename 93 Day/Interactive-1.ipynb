# %% [markdown]
# Connected to dl_env (Python 3.11.8)

# %%
from bs4 import BeautifulSoup
import requests



get_html_txt = requests.get("https://evosportsfuel.de/").text


soup_evo = BeautifulSoup(get_html_txt, "html.parser")
print(soup_evo.prettify)
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
#
# <html class="no-js" dir="ltr" lang="de">
# <head>
# <link href="https://gdpr-legal-cookie.beeclever.app" rel="preconnect"/>
# <link as="script" href="https://gdpr-legal-cookie.beeclever.app/get-script.php?shop=evo-sports-fuel.myshopify.com" rel="preload"/> <script>
#             var sDomain = location.host;
#
#             /****** Start thirdPartyScriptDefinition ******/
#             (function(){
#                   window.thirdPartyScriptDefinition = [
#
#                   ]
#               })();
#               /****** End thirdPartyScriptDefinition ******/
#
#
#
#
#
# /**
# ################################## BEECLEVER GMBH KOBLENZ ###################################
# ##### Copyright (c) 2019-present, beeclever GmbH Koblenz DE, All rights reserved.       #####
# ##### THE SOFTWARE IS PROVIDED 'AS IS', WITHOUT WARRANTY OF ANY KIND, EXPRESS OR        #####
# ...
