# %%
HANGMANPICS = ['''
  +---+
  |   |
      |
      |
      |
      |
=========''', '''
  +---+
  |   |
  O   |
      |
      |
      |
=========''', '''
  +---+
  |   |
  O   |
  |   |
      |
      |
=========''', '''
  +---+
  |   |
  O   |
 /|   |
      |
      |
=========''', '''
  +---+
  |   |
  O   |
 /|\  |
      |
      |
=========''', '''
  +---+
  |   |
  O   |
 /|\  |
 /    |
      |
=========''', '''
  +---+
  |   |
  O   |
 /|\  |
 / \  |
      |
=========''']

# %%
import random

words = ('ant baboon badger bat bear beaver camel cat clam cobra cougar '
         'coyote crow deer dog donkey duck eagle ferret fox frog goat '
         'goose hawk lion lizard llama mole monkey moose mouse mule newt '
         'otter owl panda parrot pigeon python rabbit ram rat raven '
         'rhino salmon seal shark sheep skunk sloth snake spider '
         'stork swan tiger toad trout turkey turtle weasel whale wolf '
         'wombat zebra ').split()

rand_pick_word = random.choice(words)
rand_pick_word = [val for val in rand_pick_word]

letter_list = ["_" for val in range(len(rand_pick_word))]
win = True
counter = 0
while "_" in letter_list:
    print(" ".join(letter_list))
    print(HANGMANPICS[counter])

    choose_letter = input("Guess a letter: ").lower()
    if choose_letter not in rand_pick_word:
        counter += 1
        print(counter)
        # Hangman +1

    elif choose_letter in rand_pick_word:
        for position in range(len(rand_pick_word)):
            if rand_pick_word[position] == choose_letter:
                letter_list[position] = choose_letter
    elif counter == len(rand_pick_word):
        win = False
        break

    if choose_letter == "#":
        break
print(" ".join(letter_list)+"\n")

if win == True:
    print(f"Your word was " + "".join(rand_pick_word)+". You won!")
else:
    print(f"Your word was " + "".join(rand_pick_word)+". You lost!")
# Out:
# _ _ _ _
#
#   +---+
#   |   |
#       |
#       |
#       |
#       |
# =========
# 1
# _ _ _ _
#
#   +---+
#   |   |
#   O   |
#       |
#       |
#       |
# =========
# d _ _ _
#
#   +---+
#   |   |
#   O   |
#       |
#       |
#       |
# =========
# 2
# d _ _ _
#
#   +---+
#   |   |
#   O   |
#   |   |
#       |
#       |
# =========
# 3
# d _ _ _
#
#   +---+
#   |   |
#   O   |
#  /|   |
#       |
#       |
# =========
# 4
# d _ _ _
#
#   +---+
#   |   |
#   O   |
#  /|\  |
#       |
#       |
# =========
# 5
# d _ _ _
#
#   +---+
#   |   |
#   O   |
#  /|\  |
#  /    |
#       |
# =========
# 6
# d _ _ _
#
#   +---+
#   |   |
#   O   |
#  /|\  |
#  / \  |
#       |
# =========
# 7
# d _ _ _
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In [61], line 19
#      17 while "_" in letter_list:
#      18     print(" ".join(letter_list))
# ---> 19     print(HANGMANPICS[counter])
#      21     choose_letter = input("Guess a letter: ").lower()
#      22     if choose_letter not in rand_pick_word:
#
# IndexError: list index out of range

# %%
import numpy as np
words = ["chicken"]
words_blank =["_______"]

rand_pick_word = random.choice(words)
rand_pick_word = [val for val in rand_pick_word]

words_blank = [val for val in words_blank]

list_index = []
if "c" in rand_pick_word:
    for val in range(len(rand_pick_word)):
        if rand_pick_word[val] == "c": list_index.append(val)
print(list_index)

# words_blank[list_index] = "c"
# Out:
# [0, 3]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [43], line 16
#      13         if rand_pick_word[val] == "c": list_index.append(val)
#      14 print(list_index)
# ---> 16 words_blank[list_index]
#
# TypeError: list indices must be integers or slices, not list
